# %%
import pandas as pd
import mplfinance as mpf
import matplotlib.pyplot as plt
from add_indicators import Indicators

ind = Indicators('XRPUSD')
doUntil = 87048

# %%
ind.plotIndicator('OBV', doUntil)

# %%
ind.plotIndicator('ATR', doUntil)

# %%
ind.plotIndicator('AD', doUntil)

# %%
ind.plotIndicator('ADX', doUntil)

# %%
ind.plotIndicator('Aroon',until)

# %%
ind.plotIndicator('MACD',doUntil)

# %%
ind.plotIndicator('RSI', doUntil)

# %%
ind.plotIndicator('SO',doUntil)

# %%
ind.plotIndicator('STC',50)

# %%
ind.plotIndicator('BB',doUntil)
# Out:
# /home/cristobal/workspace/kraken-test/add_indicators.py:681: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[       nan        nan        nan ... 0.00031021 0.00033452 0.00032589]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   tprice.loc[lDi:lDim-1,'std'] = tprice.loc[lDi:lDim-1,'typicalPrice'].rolling(span,min_periods=span).std()
